# %% [markdown]
# # Exercise 02 -  OLAP Cubes - Slicing and Dicing

# %% [markdown]
# All the databases table in this demo are based on public database samples and transformations
# - `Sakila` is a sample database created by `MySql` [Link](https://dev.mysql.com/doc/sakila/en/sakila-structure.html)
# - The postgresql version of it is called `Pagila` [Link](https://github.com/devrimgunduz/pagila)
# - The facts and dimension tables design is based on O'Reilly's public dimensional modelling tutorial schema [Link](http://archive.oreilly.com/oreillyschool/courses/dba3/index.html)
#
# Start by creating and connecting to the database by running the cells below.

# %%
# !PGPASSWORD=student createdb -h 127.0.0.1 -U student pagila_star
# !PGPASSWORD=student psql -q -h 127.0.0.1 -U student -d pagila_star -f Data/pagila-star.sql
# Out:
#  set_config
# ------------
#
# (1 row)
#
#  setval
# --------
#     200
# (1 row)
#
#  setval
# --------
#     605
# (1 row)
#
#  setval
# --------
#      16
# (1 row)
#
#  setval
# --------
#     600
# (1 row)
#
#  setval
# --------
#     109
# (1 row)
#
#  setval
# --------
#     599
# (1 row)
#
#  setval
# --------
#       1
# (1 row)
#
#  setval
# --------
#       1
# (1 row)
#
#  setval
# --------
#       1
# (1 row)
#
#  setval
# --------
#       1
# (1 row)
#
#  setval
# --------
#   48147
# (1 row)
#
#  setval
# --------
#    1000
# (1 row)
#
#  setval
# --------
#    4581
# (1 row)
#
#  setval
# --------
#       6
# (1 row)
#
#  setval
# --------
#   32098
# (1 row)
#
#  setval
# --------
#   16049
# (1 row)
#
#  setval
# --------
#       2
# (1 row)
#
#  setval
# --------
#       2
# (1 row)

# %% [markdown]
# ### Connect to the local database where Pagila is loaded

# %%
import sql
# %load_ext sql

DB_ENDPOINT = "127.0.0.1"
DB = 'pagila_star'
DB_USER = 'student'
DB_PASSWORD = 'student'
DB_PORT = '5432'

# postgresql://username:password@host:port/database
conn_string = "postgresql://{}:{}@{}:{}/{}" \
                        .format(DB_USER, DB_PASSWORD, DB_ENDPOINT, DB_PORT, DB)

print(conn_string)
# %sql $conn_string
# Out:
# postgresql://student:student@127.0.0.1:5432/pagila_star
# 'Connected: student@pagila_star'

# %% [markdown]
# ### Star Schema

# %% [markdown]
# <img src="pagila-star.png" width="50%"/>

# %% [markdown]
# # Start with a simple cube
# TODO: Write a query that calculates the revenue (sales_amount) by day, rating, and city. Remember to join with the appropriate dimension tables to replace the keys with the dimension labels. Sort by revenue in descending order and limit to the first 20 rows. The first few rows of your output should match the table below.

# %%
# %%time
# %%sql

SELECT d.day, m.rating, c.city, sum(s.sales_amount)
FROM factsales AS s 
INNER JOIN dimdate AS d on s.date_key = d.date_key 
INNER JOIN dimmovie AS m on s.movie_key = m.movie_key
INNER JOIN dimcustomer AS c ON c.customer_key = s.customer_key
GROUP BY (d.day, m.rating, c.city)
ORDER BY sum(s.sales_amount) DESC
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 14167 rows affected.
# CPU times: user 30.2 ms, sys: 325 µs, total: 30.5 ms
# Wall time: 183 ms
# [(30, 'G', 'San Bernardino', Decimal('74.91')),
#  (30, 'NC-17', 'Apeldoorn', Decimal('71.85')),
#  (21, 'NC-17', 'Belm', Decimal('68.91')),
#  (21, 'G', 'Citt del Vaticano', Decimal('65.91')),
#  (28, 'R', 'Mwanza', Decimal('65.91')),
#  (30, 'PG-13', 'Zanzibar', Decimal('65.91')),
#  (28, 'PG-13', 'Dhaka', Decimal('59.91')),
#  (22, 'R', 'Yangor', Decimal('59.91')),
#  (17, 'G', 'Rajkot', Decimal('59.91')),
#  (1, 'R', 'Qomsheh', Decimal('59.91')),
#  (19, 'PG', 'Najafabad', Decimal('59.88')),
#  (30, 'R', 'Fengshan', Decimal('59.85')),
#  (28, 'PG', 'So Leopoldo', Decimal('56.94')),
#  (21, 'G', 'Wroclaw', Decimal('56.94')),
#  (1, 'NC-17', 'Memphis', Decimal('56.91')),
#  (19, 'PG', 'Sokoto', Decimal('56.91')),
#  (29, 'PG-13', 'Shimoga', Decimal('56.91')),
#  (30, 'PG-13', 'Osmaniye', Decimal('56.91')),
#  (30, 'G', 'Omdurman', Decimal('56.91')),
#  (21, 'PG-13', 'Asuncin', Decimal('56.85')),
#  (23, 'NC-17', 'Adana', Decimal('53.94')),
#  (19, 'G', 'Ozamis', Decimal('53.94')),
#  (21, 'PG-13', 'Parbhani', Decimal('53.94')),
#  (30, 'PG-13', 'Nagareyama', Decimal('53.94')),
#  (20, 'PG-13', 'Baha Blanca', Decimal('53.94')),
#  (18, 'R', 'Sumy', Decimal('53.94')),
#  (30, 'G', 'Tychy', Decimal('53.94')),
#  (2, 'NC-17', 'Valparai', Decimal('53.94')),
#  (12, 'NC-17', 'Plock', Decimal('53.94')),
#  (19, 'PG', 'Loja', Decimal('53.94')),
#  (19, 'R', 'Kowloon and New Kowloon', Decimal('53.91')),
#  (30, 'R', 'Robamba', Decimal('53.91')),
#  (19, 'NC-17', 'Lengshuijiang', Decimal('53.91')),
#  (17, 'R', 'Birgunj', Decimal('53.91')),
#  (30, 'PG-13', 'Tanauan', Decimal('53.88')),
#  (17, 'PG-13', 'Ikerre', Decimal('53.85')),
#  (21, 'PG', 'Zhoushan', Decimal('50.94')),
#  (17, 'R', 'NDjamna', Decimal('50.94')),
#  (1, 'NC-17', 'Gatineau', Decimal('50.94')),
#  (2, 'NC-17', 'Kuwana', Decimal('50.94')),
#  (30, 'PG-13', 'Zhoushan', Decimal('50.94')),
#  (11, 'R', 'Gandhinagar', Decimal('50.94')),
#  (10, 'NC-17', 'Vijayawada', Decimal('50.94')),
#  (10, 'G', 'Omdurman', Decimal('50.94')),
#  (30, 'PG-13', 'Yerevan', Decimal('50.91')),
#  (9, 'G', 'Fontana', Decimal('50.91')),
#  (29, 'R', 'Baiyin', Decimal('50.91')),
#  (30, 'PG-13', 'Newcastle', Decimal('50.91')),
#  (19, 'NC-17', 'Tangail', Decimal('50.91')),
#  (28, 'R', 'Usolje-Sibirskoje', Decimal('50.91')),
#  (30, 'R', 'San Lorenzo', Decimal('50.91')),
#  (18, 'NC-17', 'Salzburg', Decimal('50.91')),
#  (20, 'R', 'Cuman', Decimal('47.94')),
#  (30, 'R', 'So Bernardo do Campo', Decimal('47.94')),
#  (28, 'PG', 'Naala-Porto', Decimal('47.94')),
#  (18, 'R', 'Juazeiro do Norte', Decimal('47.94')),
#  (28, 'NC-17', 'Mexicali', Decimal('47.94')),
#  (17, 'PG-13', 'Yantai', Decimal('47.94')),
#  (8, 'PG-13', 'Pontianak', Decimal('47.94')),
#  (29, 'R', 'Atlixco', Decimal('47.94')),
#  (20, 'PG-13', 'Santa Rosa', Decimal('47.94')),
#  (30, 'G', 'Yinchuan', Decimal('47.94')),
#  (30, 'NC-17', 'Vancouver', Decimal('47.94')),
#  (1, 'G', 'Songkhla', Decimal('47.94')),
#  (18, 'NC-17', 'Ahmadnagar', Decimal('47.94')),
#  (30, 'PG-13', 'Santa Rosa', Decimal('47.94')),
#  (6, 'NC-17', 'Phnom Penh', Decimal('47.94')),
#  (20, 'G', 'Liaocheng', Decimal('47.94')),
#  (17, 'G', 'Ondo', Decimal('47.94')),
#  (30, 'NC-17', 'Quilmes', Decimal('47.94')),
#  (8, 'PG', 'Benin City', Decimal('47.94')),
#  (1, 'PG', 'El Monte', Decimal('47.94')),
#  (16, 'R', 'Athenai', Decimal('47.94')),
#  (19, 'PG', 'Akron', Decimal('47.94')),
#  (27, 'G', 'Salala', Decimal('47.94')),
#  (30, 'PG', 'Purnea (Purnia)', Decimal('47.94')),
#  (18, 'PG', 'Kamarhati', Decimal('47.91')),
#  (17, 'PG', 'Kakamigahara', Decimal('47.91')),
#  (30, 'NC-17', 'Nakhon Sawan', Decimal('47.91')),
#  (30, 'PG-13', 'Toulouse', Decimal('47.91')),
#  (29, 'PG', 'Huejutla de Reyes', Decimal('47.91')),
#  (23, 'PG-13', 'Tiefa', Decimal('47.91')),
#  (30, 'G', 'Hohhot', Decimal('47.91')),
#  (17, 'G', 'Usak', Decimal('47.91')),
#  (17, 'NC-17', 'Lancaster', Decimal('47.91')),
#  (10, 'PG-13', 'Udaipur', Decimal('47.91')),
#  (1, 'PG-13', 'Moscow', Decimal('47.91')),
#  (20, 'PG-13', 'Johannesburg', Decimal('47.91')),
#  (21, 'R', 'Nam Dinh', Decimal('47.88')),
#  (10, 'G', 'Goinia', Decimal('44.94')),
#  (30, 'G', 'Serpuhov', Decimal('44.94')),
#  (19, 'G', 'Allende', Decimal('44.94')),
#  (6, 'NC-17', 'Konotop', Decimal('44.94')),
#  (29, 'PG-13', 'Gaziantep', Decimal('44.94')),
#  (27, 'PG-13', 'Sawhaj', Decimal('44.94')),
#  (12, 'PG-13', 'Usolje-Sibirskoje', Decimal('44.94')),
#  (12, 'PG', 'Portoviejo', Decimal('44.94')),
#  (16, 'PG', 'Skikda', Decimal('44.94')),
#  (29, 'NC-17', 'Osmaniye', Decimal('44.94')),
#  (8, 'NC-17', 'Quilmes', Decimal('44.94')),
#  (22, 'G', 'Erlangen', Decimal('44.94')),
#  (29, 'G', 'Vila Velha', Decimal('44.94')),
#  (19, 'PG-13', 'Owo', Decimal('44.94')),
#  (18, 'PG-13', 'Okayama', Decimal('44.94')),
#  (8, 'NC-17', 'Vila Velha', Decimal('44.94')),
#  (30, 'NC-17', 'Halisahar', Decimal('44.94')),
#  (27, 'PG-13', 'Gulbarga', Decimal('44.94')),
#  (8, 'PG', 'Bellevue', Decimal('44.94')),
#  (19, 'PG-13', 'Touliu', Decimal('44.94')),
#  (30, 'R', 'Changhwa', Decimal('44.94')),
#  (27, 'NC-17', 'Tianjin', Decimal('44.94')),
#  (1, 'PG', 'Rajkot', Decimal('44.94')),
#  (18, 'G', 'Omiya', Decimal('44.94')),
#  (21, 'PG-13', 'Aden', Decimal('44.94')),
#  (28, 'G', 'Tanshui', Decimal('44.94')),
#  (30, 'PG', 'Akron', Decimal('44.94')),
#  (28, 'R', 'Otsu', Decimal('44.94')),
#  (28, 'R', 'Papeete', Decimal('44.94')),
#  (18, 'PG-13', 'Cavite', Decimal('44.91')),
#  (18, 'PG-13', 'Shimonoseki', Decimal('44.91')),
#  (20, 'G', 'Aurora', Decimal('44.91')),
#  (27, 'PG-13', 'Phnom Penh', Decimal('44.91')),
#  (21, 'PG', 'Tanza', Decimal('44.91')),
#  (30, 'R', 'Satna', Decimal('44.91')),
#  (1, 'PG', 'Santiago de los Caballeros', Decimal('44.91')),
#  (21, 'NC-17', 'Kolpino', Decimal('44.91')),
#  (7, 'PG', 'Citt del Vaticano', Decimal('44.91')),
#  (30, 'NC-17', 'Mukateve', Decimal('44.91')),
#  (18, 'NC-17', 'Coquimbo', Decimal('44.91')),
#  (19, 'NC-17', 'London', Decimal('44.91')),
#  (30, 'NC-17', 'Warren', Decimal('44.91')),
#  (20, 'PG-13', 'Ciparay', Decimal('44.91')),
#  (30, 'NC-17', 'Kermanshah', Decimal('41.94')),
#  (29, 'PG-13', 'Jedda', Decimal('41.94')),
#  (7, 'G', 'Soshanguve', Decimal('41.94')),
#  (11, 'PG', 'Laredo', Decimal('41.94')),
#  (20, 'PG-13', 'Naju', Decimal('41.94')),
#  (30, 'NC-17', 'Shanwei', Decimal('41.94')),
#  (21, 'G', 'Olomouc', Decimal('41.94')),
#  (21, 'PG-13', 'Apeldoorn', Decimal('41.94')),
#  (22, 'R', 'Nakhon Sawan', Decimal('41.94')),
#  (12, 'NC-17', 'Battambang', Decimal('41.94')),
#  (29, 'PG-13', 'Maikop', Decimal('41.94')),
#  (17, 'R', 'Cuman', Decimal('41.94')),
#  (9, 'G', 'Touliu', Decimal('41.94')),
#  (27, 'PG-13', 'Idfu', Decimal('41.94')),
#  (23, 'R', 'Joliet', Decimal('41.94')),
#  (6, 'NC-17', 'Santa F', Decimal('41.94')),
#  (22, 'NC-17', 'Halisahar', Decimal('41.94')),
#  (9, 'R', 'Kowloon and New Kowloon', Decimal('41.94')),
#  (2, 'PG', 'Imus', Decimal('41.94')),
#  (2, 'NC-17', 'Cayenne', Decimal('41.94')),
#  (30, 'G', 'Davao', Decimal('41.94')),
#  (19, 'PG', 'Maracabo', Decimal('41.94')),
#  (30, 'G', 'Liaocheng', Decimal('41.94')),
#  (30, 'NC-17', 'Isesaki', Decimal('41.94')),
#  (23, 'PG', 'Donostia-San Sebastin', Decimal('41.94')),
#  (17, 'PG-13', 'Tanza', Decimal('41.94')),
#  (8, 'NC-17', 'Omiya', Decimal('41.94')),
#  (9, 'PG-13', 'Baicheng', Decimal('41.94')),
#  (29, 'G', 'Bucuresti', Decimal('41.94')),
#  (23, 'NC-17', 'Urawa', Decimal('41.94')),
#  (20, 'PG', 'Huaian', Decimal('41.94')),
#  (27, 'NC-17', 'Iwaki', Decimal('41.94')),
#  (30, 'NC-17', 'Chatsworth', Decimal('41.94')),
#  (19, 'NC-17', 'Syrakusa', Decimal('41.94')),
#  (20, 'NC-17', 'Changzhou', Decimal('41.94')),
#  (30, 'PG', 'Cabuyao', Decimal('41.94')),
#  (1, 'PG-13', 'Haiphong', Decimal('41.94')),
#  (28, 'R', 'Parbhani', Decimal('41.94')),
#  (27, 'G', 'Dhaka', Decimal('41.94')),
#  (29, 'PG-13', 'Qomsheh', Decimal('41.94')),
#  (30, 'R', 'Yinchuan', Decimal('41.94')),
#  (8, 'R', 'El Fuerte', Decimal('41.94')),
#  (16, 'G', 'Chungho', Decimal('41.94')),
#  (30, 'R', 'Maracabo', Decimal('41.94')),
#  (21, 'NC-17', 'Tartu', Decimal('41.94')),
#  (21, 'NC-17', 'Shimoga', Decimal('41.94')),
#  (26, 'G', 'Ashgabat', Decimal('41.94')),
#  (30, 'R', 'Sagamihara', Decimal('41.94')),
#  (20, 'NC-17', 'Kowloon and New Kowloon', Decimal('41.94')),
#  (29, 'PG-13', 'Cuauhtmoc', Decimal('41.94')),
#  (19, 'PG', 'Cam Ranh', Decimal('41.94')),
#  (15, 'PG-13', 'Valparai', Decimal('41.94')),
#  (22, 'PG', 'Saint-Denis', Decimal('41.94')),
#  (11, 'PG-13', 'Boa Vista', Decimal('41.94')),
#  (21, 'PG-13', 'Lublin', Decimal('41.94')),
#  (19, 'PG', 'Sawhaj', Decimal('41.94')),
#  (20, 'G', 'Mannheim', Decimal('41.94')),
#  (17, 'G', 'Hubli-Dharwad', Decimal('41.94')),
#  (21, 'PG-13', 'Maracabo', Decimal('41.91')),
#  (30, 'NC-17', 'Lengshuijiang', Decimal('41.91')),
#  (18, 'R', 'Pyongyang', Decimal('41.91')),
#  (27, 'NC-17', 'Funafuti', Decimal('41.91')),
#  (30, 'PG-13', 'Boksburg', Decimal('41.91')),
#  (18, 'PG', 'Lima', Decimal('41.91')),
#  (21, 'PG', 'Ogbomosho', Decimal('41.91')),
#  (7, 'PG-13', 'Avellaneda', Decimal('41.91')),
#  (29, 'G', 'Jhansi', Decimal('41.91')),
#  (20, 'PG-13', 'Boa Vista', Decimal('41.88')),
#  (10, 'PG', 'Izumisano', Decimal('38.94')),
#  (30, 'NC-17', 'Buenaventura', Decimal('38.94')),
#  (20, 'R', 'Xinxiang', Decimal('38.94')),
#  (22, 'G', 'Touliu', Decimal('38.94')),
#  (11, 'PG-13', 'Ife', Decimal('38.94')),
#  (21, 'PG', 'Kuching', Decimal('38.94')),
#  (6, 'R', 'Apeldoorn', Decimal('38.94')),
#  (28, 'R', 'Citrus Heights', Decimal('38.94')),
#  (29, 'G', 'Junan', Decimal('38.94')),
#  (2, 'NC-17', 'Atlixco', Decimal('38.94')),
#  (18, 'NC-17', 'Coacalco de Berriozbal', Decimal('38.94')),
#  (18, 'PG-13', 'Udaipur', Decimal('38.94')),
#  (6, 'R', 'Erlangen', Decimal('38.94')),
#  (27, 'R', 'Hunuco', Decimal('38.94')),
#  (27, 'R', 'Merlo', Decimal('38.94')),
#  (1, 'G', 'Benin City', Decimal('38.94')),
#  (27, 'PG', 'Okinawa', Decimal('38.94')),
#  (27, 'PG', 'Fontana', Decimal('38.94')),
#  (7, 'PG-13', 'La Paz', Decimal('38.94')),
#  (19, 'PG', 'Lengshuijiang', Decimal('38.94')),
#  (28, 'R', 'Newcastle', Decimal('38.94')),
#  (1, 'NC-17', 'Tel Aviv-Jaffa', Decimal('38.94')),
#  (12, 'R', 'Sanya', Decimal('38.94')),
#  (6, 'G', 'ostka', Decimal('38.94')),
#  (19, 'PG-13', 'Pemalang', Decimal('38.94')),
#  (7, 'PG', 'al-Qatif', Decimal('38.94')),
#  (28, 'G', 'Denizli', Decimal('38.94')),
#  (29, 'PG-13', 'Aden', Decimal('38.94')),
#  (10, 'G', 'Yinchuan', Decimal('38.94')),
#  (10, 'G', 'Zhezqazghan', Decimal('38.94')),
#  (28, 'G', 'Ourense (Orense)', Decimal('38.94')),
#  (15, 'G', 'So Bernardo do Campo', Decimal('38.94')),
#  (18, 'PG-13', 'Yangor', Decimal('38.94')),
#  (18, 'PG-13', 'Kimberley', Decimal('38.94')),
#  (2, 'NC-17', 'Lapu-Lapu', Decimal('38.94')),
#  (21, 'PG', 'Bijapur', Decimal('38.94')),
#  (5, 'PG-13', 'Nha Trang', Decimal('38.94')),
#  (1, 'R', 'Kragujevac', Decimal('38.94')),
#  (27, 'G', 'Cape Coral', Decimal('38.94')),
#  (17, 'PG', 'Davao', Decimal('38.94')),
#  (28, 'NC-17', 'Dundee', Decimal('38.94')),
#  (18, 'PG-13', 'Ibirit', Decimal('38.94')),
#  (27, 'G', 'Athenai', Decimal('38.94')),
#  (17, 'PG-13', 'Usolje-Sibirskoje', Decimal('38.94')),
#  (17, 'PG-13', 's-Hertogenbosch', Decimal('38.94')),
#  (17, 'R', 'Balurghat', Decimal('38.94')),
#  (30, 'PG', 'Mannheim', Decimal('38.94')),
#  (18, 'R', 'Kansas City', Decimal('38.94')),
#  (20, 'G', 'Bhimavaram', Decimal('38.94')),
#  (30, 'PG', 'Lancaster', Decimal('38.94')),
#  (17, 'R', 'Rockford', Decimal('38.94')),
#  (17, 'R', 'Sterling Heights', Decimal('38.94')),
#  (1, 'R', 'Pjatigorsk', Decimal('38.94')),
#  (21, 'PG-13', 'Etawah', Decimal('38.94')),
#  (21, 'PG-13', 'Firozabad', Decimal('38.94')),
#  (30, 'G', 'Simferopol', Decimal('38.94')),
#  (17, 'NC-17', 'Arlington', Decimal('38.94')),
#  (20, 'PG', 'Rizhao', Decimal('38.94')),
#  (23, 'R', 'Apeldoorn', Decimal('38.94')),
#  (30, 'R', 'Benguela', Decimal('38.94')),
#  (21, 'NC-17', 'Bergamo', Decimal('38.94')),
#  (18, 'NC-17', 'Araatuba', Decimal('38.94')),
#  (2, 'R', 'Huixquilucan', Decimal('38.94')),
#  (12, 'G', 'Chiayi', Decimal('38.94')),
#  (21, 'PG-13', 'Masqat', Decimal('38.94')),
#  (22, 'NC-17', 'Ilorin', Decimal('38.94')),
#  (20, 'R', 'Araatuba', Decimal('38.94')),
#  (21, 'G', 'Grand Prairie', Decimal('38.94')),
#  (9, 'PG-13', 'Mysore', Decimal('38.94')),
#  (30, 'R', 'Liaocheng', Decimal('38.94')),
#  (11, 'R', 'Cape Coral', Decimal('38.94')),
#  (19, 'NC-17', 'Pyongyang', Decimal('38.91')),
#  (8, 'PG-13', 'Bucuresti', Decimal('38.91')),
#  (30, 'G', 'Elista', Decimal('38.91')),
#  (22, 'PG-13', 'Ondo', Decimal('38.91')),
#  (30, 'PG', 'Isesaki', Decimal('38.91')),
#  (17, 'G', 'San Felipe del Progreso', Decimal('38.91')),
#  (21, 'NC-17', 'Richmond Hill', Decimal('38.91')),
#  (30, 'PG-13', 'Shaoguan', Decimal('38.91')),
#  (27, 'PG-13', 'Quilmes', Decimal('38.91')),
#  (6, 'NC-17', 'Korla', Decimal('38.91')),
#  (20, 'PG-13', 'Vilnius', Decimal('38.91')),
#  (21, 'G', 'Tabriz', Decimal('38.91')),
#  (19, 'R', 'Juiz de Fora', Decimal('38.91')),
#  (26, 'PG-13', 'Iwaki', Decimal('38.91')),
#  (18, 'NC-17', 'Najafabad', Decimal('38.91')),
#  (30, 'PG', 'Salamanca', Decimal('38.88')),
#  (7, 'PG-13', 'Juiz de Fora', Decimal('35.97')),
#  (23, 'NC-17', 'Siegen', Decimal('35.97')),
#  (22, 'G', 'Usak', Decimal('35.97')),
#  (6, 'G', 'Szkesfehrvr', Decimal('35.97')),
#  (25, 'PG-13', 'Mannheim', Decimal('35.97')),
#  (21, 'PG-13', 'Pemalang', Decimal('35.97')),
#  (2, 'R', 'Naju', Decimal('35.97')),
#  (26, 'NC-17', 'Siliguri (Shiliguri)', Decimal('35.94')),
#  (28, 'PG', 'Naju', Decimal('35.94')),
#  (17, 'R', 'Monclova', Decimal('35.94')),
#  (1, 'PG-13', 'Iwakuni', Decimal('35.94')),
#  (21, 'R', 'Tieli', Decimal('35.94')),
#  (30, 'NC-17', 'Sungai Petani', Decimal('35.94')),
#  (30, 'PG-13', 'Ivanovo', Decimal('35.94')),
#  (27, 'G', 'Juiz de Fora', Decimal('35.94')),
#  (2, 'G', 'Rustenburg', Decimal('35.94')),
#  (30, 'PG', 'Po', Decimal('35.94')),
#  (19, 'PG', 'Bilbays', Decimal('35.94')),
#  (27, 'PG-13', 'Vijayawada', Decimal('35.94')),
#  (10, 'R', 'Czestochowa', Decimal('35.94')),
#  (16, 'PG', 'Cape Coral', Decimal('35.94')),
#  (1, 'R', 'El Fuerte', Decimal('35.94')),
#  (18, 'NC-17', 'Urawa', Decimal('35.94')),
#  (27, 'NC-17', 'Ambattur', Decimal('35.94')),
#  (20, 'NC-17', 'Kabul', Decimal('35.94')),
#  (31, 'R', 'Tabuk', Decimal('35.94')),
#  (20, 'NC-17', 'Nakhon Sawan', Decimal('35.94')),
#  (21, 'PG-13', 'Tychy', Decimal('35.94')),
#  (21, 'R', 'Firozabad', Decimal('35.94')),
#  (9, 'PG-13', 'Kaliningrad', Decimal('35.94')),
#  (28, 'R', 'Esfahan', Decimal('35.94')),
#  (30, 'R', 'Sumqayit', Decimal('35.94')),
#  (29, 'PG-13', 'Southport', Decimal('35.94')),
#  (27, 'PG-13', 'Mardan', Decimal('35.94')),
#  (30, 'G', 'Kursk', Decimal('35.94')),
#  (17, 'G', 'Czestochowa', Decimal('35.94')),
#  (28, 'PG-13', 'Elista', Decimal('35.94')),
#  (29, 'PG-13', 'Uluberia', Decimal('35.94')),
#  (11, 'NC-17', 'Johannesburg', Decimal('35.94')),
#  (20, 'NC-17', 'Imus', Decimal('35.94')),
#  (27, 'NC-17', 'Jhansi', Decimal('35.94')),
#  (20, 'R', 'Nantou', Decimal('35.94')),
#  (20, 'PG', 'Jalib al-Shuyukh', Decimal('35.94')),
#  (19, 'R', 'Ife', Decimal('35.94')),
#  (23, 'R', 'Quilmes', Decimal('35.94')),
#  (28, 'PG-13', 'Shubra al-Khayma', Decimal('35.94')),
#  (22, 'R', 'Ikerre', Decimal('35.94')),
#  (1, 'NC-17', 'Botshabelo', Decimal('35.94')),
#  (18, 'PG', 'Rampur', Decimal('35.94')),
#  (15, 'PG-13', 'Sumy', Decimal('35.94')),
#  (22, 'G', 'Kisumu', Decimal('35.94')),
#  (2, 'PG-13', 'Antofagasta', Decimal('35.94')),
#  (28, 'PG-13', 'Smolensk', Decimal('35.94')),
#  (30, 'R', 'Valle de la Pascua', Decimal('35.94')),
#  (18, 'R', 'Brindisi', Decimal('35.94')),
#  (21, 'NC-17', 'Charlotte Amalie', Decimal('35.94')),
#  (18, 'G', 'Monywa', Decimal('35.94')),
#  (15, 'PG-13', 'Iwatsuki', Decimal('35.94')),
#  (22, 'G', 'Mysore', Decimal('35.94')),
#  (18, 'NC-17', 'Santa F', Decimal('35.94')),
#  (1, 'PG-13', 'Miyakonojo', Decimal('35.94')),
#  (30, 'PG-13', 'La Romana', Decimal('35.94')),
#  (29, 'NC-17', 'Sorocaba', Decimal('35.94')),
#  (30, 'PG-13', 'Lhokseumawe', Decimal('35.94')),
#  (30, 'G', 'Jining', Decimal('35.94')),
#  (20, 'R', 'Jaffna', Decimal('35.94')),
#  (10, 'NC-17', 'Lincoln', Decimal('35.94')),
#  (12, 'PG-13', 'Portoviejo', Decimal('35.94')),
#  (27, 'R', 'Halle/Saale', Decimal('35.94')),
#  (30, 'PG', 'Yamuna Nagar', Decimal('35.94')),
#  (30, 'R', 'Siegen', Decimal('35.94')),
#  (30, 'G', 'Zaria', Decimal('35.94')),
#  (23, 'G', 'Huixquilucan', Decimal('35.94')),
#  (20, 'PG-13', 'Lancaster', Decimal('35.94')),
#  (20, 'PG-13', 'Maring', Decimal('35.94')),
#  (21, 'R', 'Mannheim', Decimal('35.94')),
#  (29, 'G', 'Rampur', Decimal('35.94')),
#  (23, 'G', 'Lancaster', Decimal('35.94')),
#  (10, 'PG-13', 'San Felipe del Progreso', Decimal('35.94')),
#  (19, 'PG-13', 'Angra dos Reis', Decimal('35.94')),
#  (18, 'PG-13', 'Uluberia', Decimal('35.94')),
#  (30, 'PG-13', 'Apeldoorn', Decimal('35.94')),
#  (29, 'G', 'Koriyama', Decimal('35.94')),
#  (17, 'G', 'Kilis', Decimal('35.94')),
#  (23, 'PG', 'Tieli', Decimal('35.94')),
#  (20, 'G', 'Rancagua', Decimal('35.94')),
#  (23, 'PG', 'Pontianak', Decimal('35.94')),
#  (18, 'G', 'Tangail', Decimal('35.94')),
#  (20, 'G', 'Qomsheh', Decimal('35.94')),
#  (14, 'PG-13', 'London', Decimal('35.94')),
#  (21, 'PG-13', 'Bern', Decimal('35.94')),
#  (17, 'PG-13', 'Zapopan', Decimal('35.94')),
#  (19, 'G', 'Ashqelon', Decimal('35.94')),
#  (8, 'PG-13', 'Sivas', Decimal('35.94')),
#  (15, 'PG', 'Madiun', Decimal('35.94')),
#  (18, 'NC-17', 'Santo Andr', Decimal('35.94')),
#  (20, 'R', 'Osmaniye', Decimal('35.94')),
#  (30, 'PG', 'Mysore', Decimal('35.94')),
#  (22, 'PG', 'Huaian', Decimal('35.91')),
#  (27, 'NC-17', 'Beira', Decimal('35.91')),
#  (1, 'NC-17', 'Bayugan', Decimal('35.91')),
#  (30, 'R', 'Udine', Decimal('35.91')),
#  (30, 'R', 'Ashdod', Decimal('35.91')),
#  (18, 'PG-13', 'Xiangfan', Decimal('35.91')),
#  (26, 'R', 'Toulon', Decimal('32.97')),
#  (30, 'G', 'Warren', Decimal('32.97')),
#  (10, 'NC-17', 'Nha Trang', Decimal('32.97')),
#  (1, 'PG-13', 'Florencia', Decimal('32.97')),
#  (21, 'R', 'San Lorenzo', Decimal('32.97')),
#  (30, 'G', 'Yantai', Decimal('32.97')),
#  (20, 'G', 'Ashgabat', Decimal('32.97')),
#  (25, 'R', 'Callao', Decimal('32.97')),
#  (23, 'NC-17', 'Pavlodar', Decimal('32.97')),
#  (27, 'PG', 'Xintai', Decimal('32.97')),
#  (2, 'R', 'Rae Bareli', Decimal('32.97')),
#  (19, 'NC-17', 'Zhoushan', Decimal('32.97')),
#  (21, 'NC-17', 'Rockford', Decimal('32.97')),
#  (1, 'PG-13', 'Bhimavaram', Decimal('32.97')),
#  (22, 'PG-13', 'Ogbomosho', Decimal('32.97')),
#  (18, 'R', 'Daugavpils', Decimal('32.97')),
#  (30, 'NC-17', 'Erlangen', Decimal('32.97')),
#  (28, 'G', 'Kermanshah', Decimal('32.97')),
#  (21, 'PG-13', 'Cavite', Decimal('32.97')),
#  (30, 'G', 'Mannheim', Decimal('32.97')),
#  (16, 'PG', 'Battambang', Decimal('32.97')),
#  (22, 'NC-17', 'Kaliningrad', Decimal('32.97')),
#  (8, 'R', 'Ozamis', Decimal('32.97')),
#  (7, 'PG', 'Santa F', Decimal('32.97')),
#  (9, 'NC-17', 'Santa Brbara dOeste', Decimal('32.97')),
#  (9, 'PG', 'Shimonoseki', Decimal('32.97')),
#  (2, 'NC-17', 'Cabuyao', Decimal('32.97')),
#  (22, 'PG-13', 'Rampur', Decimal('32.97')),
#  (9, 'G', 'Brockton', Decimal('32.97')),
#  (17, 'R', 'Jinchang', Decimal('32.97')),
#  (15, 'PG-13', 'Alessandria', Decimal('32.97')),
#  (30, 'NC-17', 'Batna', Decimal('32.97')),
#  (10, 'G', 'Parbhani', Decimal('32.97')),
#  (22, 'PG-13', 'Iwakuni', Decimal('32.97')),
#  (27, 'PG-13', 'Purnea (Purnia)', Decimal('32.97')),
#  (20, 'G', 'Tangail', Decimal('32.97')),
#  (2, 'PG-13', 'Saint-Denis', Decimal('32.97')),
#  (2, 'PG-13', 'Richmond Hill', Decimal('32.97')),
#  (23, 'NC-17', 'Antofagasta', Decimal('32.97')),
#  (30, 'PG-13', 'Jinzhou', Decimal('32.97')),
#  (6, 'NC-17', 'Ibirit', Decimal('32.97')),
#  (30, 'G', 'Gorontalo', Decimal('32.97')),
#  (10, 'R', 'Guadalajara', Decimal('32.97')),
#  (2, 'PG-13', 'Probolinggo', Decimal('32.97')),
#  (20, 'PG', 'Pangkal Pinang', Decimal('32.97')),
#  (28, 'G', 'Songkhla', Decimal('32.97')),
#  (2, 'R', 'Bijapur', Decimal('32.97')),
#  (29, 'PG', 'Duisburg', Decimal('32.97')),
#  (6, 'PG', 'Sumy', Decimal('32.97')),
#  (1, 'PG', 'Smolensk', Decimal('32.97')),
#  (1, 'G', 'Hunuco', Decimal('32.97')),
#  (8, 'PG-13', 'Mwanza', Decimal('32.97')),
#  (26, 'PG-13', 'Angra dos Reis', Decimal('32.97')),
#  (18, 'PG', 'Hodeida', Decimal('32.97')),
#  (30, 'PG-13', 'Baku', Decimal('32.97')),
#  (20, 'PG', 'Sincelejo', Decimal('32.97')),
#  (30, 'G', 'Zhezqazghan', Decimal('32.97')),
#  (29, 'NC-17', 'Uijongbu', Decimal('32.97')),
#  (10, 'R', 'Kakamigahara', Decimal('32.97')),
#  (19, 'NC-17', 'Clarksville', Decimal('32.97')),
#  (20, 'PG-13', 'Plock', Decimal('32.97')),
#  (17, 'PG', 'Datong', Decimal('32.97')),
#  (18, 'G', 'Stockport', Decimal('32.97')),
#  (19, 'PG-13', 'Blumenau', Decimal('32.97')),
#  (18, 'R', 'Konotop', Decimal('32.97')),
#  (18, 'G', 'Sharja', Decimal('32.97')),
#  (22, 'R', 'Omiya', Decimal('32.97')),
#  (20, 'G', 'Suihua', Decimal('32.97')),
#  (12, 'R', 'Saint-Denis', Decimal('32.97')),
#  (23, 'G', 'Serpuhov', Decimal('32.97')),
#  (6, 'PG-13', 'Allende', Decimal('32.97')),
#  (28, 'PG-13', 'Stockport', Decimal('32.97')),
#  (21, 'R', 'Adoni', Decimal('32.97')),
#  (26, 'PG', 'Hodeida', Decimal('32.97')),
#  (1, 'PG', 'Yamuna Nagar', Decimal('32.97')),
#  (5, 'NC-17', 'Ourense (Orense)', Decimal('32.97')),
#  (29, 'NC-17', 'San Felipe de Puerto Plata', Decimal('32.97')),
#  (21, 'NC-17', 'Zhoushan', Decimal('32.97')),
#  (29, 'NC-17', 'Garland', Decimal('32.97')),
#  (28, 'R', 'Qomsheh', Decimal('32.94')),
#  (19, 'PG-13', 'Jalib al-Shuyukh', Decimal('32.94')),
#  (28, 'R', 'Bhilwara', Decimal('32.94')),
#  (27, 'R', 'Chisinau', Decimal('32.94')),
#  (30, 'PG-13', 'Memphis', Decimal('32.94')),
#  (28, 'PG-13', 'Yantai', Decimal('32.94')),
#  (27, 'R', 'Santa Rosa', Decimal('32.94')),
#  (27, 'R', 'Yuncheng', Decimal('32.94')),
#  (6, 'R', 'Valparai', Decimal('32.94')),
#  (21, 'PG', 'Dayton', Decimal('32.94')),
#  (30, 'PG-13', 'Jelets', Decimal('32.94')),
#  (31, 'PG-13', 'Balaiha', Decimal('32.94')),
#  (18, 'R', 'Shahr-e Kord', Decimal('32.94')),
#  (7, 'PG', 'Szkesfehrvr', Decimal('32.94')),
#  (19, 'R', 'Southampton', Decimal('32.94')),
#  (28, 'PG', 'Xiangfan', Decimal('32.94')),
#  (28, 'G', 'Rae Bareli', Decimal('32.94')),
#  (21, 'PG', 'Antofagasta', Decimal('32.94')),
#  (28, 'PG', 'Sirjan', Decimal('32.94')),
#  (28, 'PG', 'Probolinggo', Decimal('32.94')),
#  (18, 'PG', 'Bhavnagar', Decimal('32.94')),
#  (18, 'R', 'Juiz de Fora', Decimal('32.94')),
#  (22, 'PG-13', 'Halifax', Decimal('32.94')),
#  (18, 'PG', 'Chandrapur', Decimal('32.94')),
#  (30, 'NC-17', 'Tonghae', Decimal('32.94')),
#  (2, 'NC-17', 'Okara', Decimal('32.94')),
#  (2, 'NC-17', 'Plock', Decimal('32.94')),
#  (9, 'R', 'Nantou', Decimal('32.94')),
#  (30, 'NC-17', 'Halifax', Decimal('32.94')),
#  (30, 'G', 'Dallas', Decimal('32.94')),
#  (22, 'R', 'Lausanne', Decimal('32.94')),
#  (21, 'R', 'Santa Brbara dOeste', Decimal('32.94')),
#  (30, 'NC-17', 'Oshawa', Decimal('32.94')),
#  (18, 'G', 'Richmond Hill', Decimal('32.94')),
#  (11, 'PG-13', 'Blumenau', Decimal('32.94')),
#  (30, 'NC-17', 'Czestochowa', Decimal('32.94')),
#  (30, 'NC-17', 'ostka', Decimal('32.94')),
#  (9, 'PG', 'Wroclaw', Decimal('32.94')),
#  (16, 'PG-13', 'Botosani', Decimal('32.94')),
#  (11, 'PG-13', 'Najafabad', Decimal('32.94')),
#  (30, 'NC-17', 'Charlotte Amalie', Decimal('32.94')),
#  (2, 'PG-13', 'Papeete', Decimal('32.94')),
#  (19, 'NC-17', 'Omiya', Decimal('32.94')),
#  (20, 'R', 'Kamjanets-Podilskyi', Decimal('32.94')),
#  (18, 'PG', 'Ljubertsy', Decimal('32.94')),
#  (20, 'PG-13', 'Tuguegarao', Decimal('32.94')),
#  (19, 'PG-13', 'Tanza', Decimal('32.94')),
#  (20, 'PG-13', 'Shanwei', Decimal('32.94')),
#  (21, 'PG-13', 'Mandaluyong', Decimal('32.94')),
#  (21, 'PG-13', 'Lubumbashi', Decimal('32.94')),
#  (18, 'PG', 'Otsu', Decimal('32.94')),
#  (30, 'PG', 'Daxian', Decimal('32.94')),
#  (16, 'PG', 'Shenzhen', Decimal('32.94')),
#  (20, 'PG-13', 'Fukuyama', Decimal('32.94')),
#  (18, 'G', 'Idfu', Decimal('32.94')),
#  (20, 'PG-13', 'Bhopal', Decimal('32.94')),
#  (23, 'PG-13', 'guas Lindas de Gois', Decimal('32.94')),
#  (20, 'PG', 'Oshawa', Decimal('32.94')),
#  (23, 'R', 'Naala-Porto', Decimal('32.94')),
#  (30, 'G', 'Tongliao', Decimal('32.94')),
#  (18, 'G', 'Coacalco de Berriozbal', Decimal('32.94')),
#  (31, 'PG', 'Klerksdorp', Decimal('32.94')),
#  (20, 'PG', 'Jakarta', Decimal('32.94')),
#  (1, 'R', 'Qinhuangdao', Decimal('32.94')),
#  (16, 'PG', 'Halisahar', Decimal('32.94')),
#  (17, 'NC-17', 'Cayenne', Decimal('32.94')),
#  (18, 'PG', 'Weifang', Decimal('32.94')),
#  (12, 'PG', 'Salinas', Decimal('32.94')),
#  (20, 'NC-17', 'Vaduz', Decimal('32.94')),
#  (12, 'PG', 'Sumqayit', Decimal('32.94')),
#  (18, 'PG-13', 'Amroha', Decimal('32.94')),
#  (17, 'R', 'Sullana', Decimal('32.94')),
#  (30, 'PG', 'Kimberley', Decimal('32.94')),
#  (21, 'PG-13', 'Chisinau', Decimal('32.94')),
#  (17, 'NC-17', 'Ibirit', Decimal('32.94')),
#  (8, 'R', 'Citt del Vaticano', Decimal('32.94')),
#  (17, 'NC-17', 'Ljubertsy', Decimal('32.94')),
#  (30, 'G', 'Ibirit', Decimal('32.94')),
#  (2, 'NC-17', 'Hsichuh', Decimal('32.94')),
#  (19, 'NC-17', 'Iwaki', Decimal('32.94')),
#  (19, 'NC-17', 'Hidalgo', Decimal('32.94')),
#  (17, 'R', 'Acua', Decimal('32.94')),
#  (8, 'PG-13', 'Jos Azueta', Decimal('32.94')),
#  (19, 'NC-17', 'Cavite', Decimal('32.94')),
#  (17, 'PG-13', 'Warren', Decimal('32.94')),
#  (17, 'PG-13', 'Vancouver', Decimal('32.94')),
#  (17, 'PG-13', 'Southend-on-Sea', Decimal('32.94')),
#  (2, 'PG-13', 'Salzburg', Decimal('32.94')),
#  (1, 'NC-17', 'Dadu', Decimal('32.94')),
#  (17, 'PG', 'Paarl', Decimal('32.94')),
#  (8, 'PG', 'Shivapuri', Decimal('32.94')),
#  (30, 'R', 'Aurora', Decimal('32.94')),
#  (18, 'PG-13', 'Iwaki', Decimal('32.94')),
#  (17, 'PG-13', 'Baicheng', Decimal('32.94')),
#  (21, 'PG', 'Witten', Decimal('32.94')),
#  (30, 'PG-13', 'Usak', Decimal('32.94')),
#  (27, 'NC-17', 'Bhilwara', Decimal('32.94')),
#  (8, 'PG', 'Batman', Decimal('32.94')),
#  (21, 'PG', 'Sanaa', Decimal('32.94')),
#  (27, 'NC-17', 'Hiroshima', Decimal('32.94')),
#  (6, 'G', 'Papeete', Decimal('32.94')),
#  (30, 'PG-13', 'Sousse', Decimal('32.94')),
#  (6, 'NC-17', 'Brest', Decimal('32.94')),
#  (29, 'PG', 'Haining', Decimal('32.94')),
#  (29, 'PG', 'Bucuresti', Decimal('32.94')),
#  (30, 'R', 'Dundee', Decimal('32.94')),
#  (8, 'NC-17', 'Bucuresti', Decimal('32.94')),
#  (29, 'NC-17', 'Yangor', Decimal('32.94')),
#  (29, 'NC-17', 'Juazeiro do Norte', Decimal('32.94')),
#  (30, 'PG-13', 'Qinhuangdao', Decimal('32.94')),
#  (27, 'PG', 'Richmond Hill', Decimal('32.94')),
#  (8, 'G', 'Kurgan', Decimal('32.94')),
#  (19, 'PG-13', 'Saint-Denis', Decimal('32.94')),
#  (29, 'G', 'Kingstown', Decimal('32.94')),
#  (29, 'G', 'Jaffna', Decimal('32.94')),
#  (29, 'G', 'Battambang', Decimal('32.94')),
#  (18, 'PG-13', 'al-Ayn', Decimal('32.94')),
#  (27, 'PG-13', 'Udine', Decimal('32.94')),
#  (27, 'PG-13', 'Uijongbu', Decimal('32.94')),
#  (22, 'NC-17', 'Laohekou', Decimal('32.91')),
#  (30, 'NC-17', 'Okinawa', Decimal('32.91')),
#  (17, 'G', 'Ahmadnagar', Decimal('32.91')),
#  (17, 'PG-13', 'Sanaa', Decimal('32.91')),
#  (21, 'PG-13', 'Peoria', Decimal('32.91')),
#  (1, 'G', 'Bratislava', Decimal('32.91')),
#  (30, 'PG', 'Saint-Denis', Decimal('32.91')),
#  (18, 'NC-17', 'Ziguinchor', Decimal('32.91')),
#  (30, 'PG-13', 'Kirovo-Tepetsk', Decimal('32.91')),
#  (30, 'NC-17', 'Kolpino', Decimal('32.91')),
#  (30, 'PG', 'Kamakura', Decimal('32.91')),
#  (27, 'PG-13', 'Uluberia', Decimal('32.91')),
#  (21, 'PG', 'Malm', Decimal('32.91')),
#  (23, 'PG-13', 'Tanshui', Decimal('32.91')),
#  (29, 'PG', 'Jinchang', Decimal('32.91')),
#  (9, 'G', 'ostka', Decimal('29.97')),
#  (29, 'NC-17', 'Qomsheh', Decimal('29.97')),
#  (21, 'PG-13', 'Bijapur', Decimal('29.97')),
#  (30, 'G', 'Baiyin', Decimal('29.97')),
#  (2, 'PG-13', 'al-Hawiya', Decimal('29.97')),
#  (20, 'PG', 'Witten', Decimal('29.97')),
#  (19, 'PG-13', 'Cuauhtmoc', Decimal('29.97')),
#  (19, 'PG-13', 'Kowloon and New Kowloon', Decimal('29.97')),
#  (28, 'NC-17', 'Pontianak', Decimal('29.97')),
#  (18, 'R', 'Southampton', Decimal('29.97')),
#  (18, 'PG', 'Gijn', Decimal('29.97')),
#  (19, 'R', 'Brescia', Decimal('29.97')),
#  (16, 'PG', 'Niznekamsk', Decimal('29.97')),
#  (28, 'R', 'Sawhaj', Decimal('29.97')),
#  (10, 'PG', 'Olomouc', Decimal('29.97')),
#  (2, 'NC-17', 'Quilmes', Decimal('29.97')),
#  (27, 'R', 'Xiangtan', Decimal('29.97')),
#  (19, 'NC-17', 'Gaziantep', Decimal('29.97')),
#  (28, 'PG', 'Hiroshima', Decimal('29.97')),
#  (17, 'R', 'Citt del Vaticano', Decimal('29.97')),
#  (16, 'PG', 'Mukateve', Decimal('29.97')),
#  (11, 'G', 'Donostia-San Sebastin', Decimal('29.97')),
#  (18, 'G', 'Mukateve', Decimal('29.97')),
#  (20, 'PG-13', 'Santa Brbara dOeste', Decimal('29.97')),
#  (18, 'PG', 'Cuauhtmoc', Decimal('29.97')),
#  (28, 'PG', 'Kamyin', Decimal('29.97')),
#  (9, 'NC-17', 'Tabriz', Decimal('29.97')),
#  (15, 'PG', 'Jedda', Decimal('29.97')),
#  (8, 'PG-13', 'Mosul', Decimal('29.97')),
#  (26, 'R', 'Antofagasta', Decimal('29.97')),
#  (6, 'NC-17', 'Nuuk', Decimal('29.97')),
#  (16, 'NC-17', 'Qalyub', Decimal('29.97')),
#  (17, 'G', 'Nantou', Decimal('29.97')),
#  (10, 'PG-13', 'Rustenburg', Decimal('29.97')),
#  (8, 'NC-17', 'Dos Quebradas', Decimal('29.97')),
#  (27, 'PG', 'Arecibo', Decimal('29.97')),
#  (8, 'PG-13', 'Kamarhati', Decimal('29.97')),
#  (7, 'PG', 'Effon-Alaiye', Decimal('29.97')),
#  (11, 'G', 'Atlixco', Decimal('29.97')),
#  (21, 'PG', 'Ipoh', Decimal('29.97')),
#  (28, 'NC-17', 'Gaziantep', Decimal('29.97')),
#  (20, 'PG', 'Probolinggo', Decimal('29.97')),
#  (17, 'G', 'Mandaluyong', Decimal('29.97')),
#  (27, 'G', 'Alvorada', Decimal('29.97')),
#  (6, 'R', 'Caracas', Decimal('29.97')),
#  (29, 'G', 'Ipoh', Decimal('29.97')),
#  (19, 'NC-17', 'Sunnyvale', Decimal('29.97')),
#  (19, 'R', 'Dos Quebradas', Decimal('29.97')),
#  (29, 'PG-13', 'Kolpino', Decimal('29.97')),
#  (20, 'PG', 'Nuuk', Decimal('29.97')),
#  (27, 'G', 'Braslia', Decimal('29.97')),
#  (30, 'PG-13', 'Huejutla de Reyes', Decimal('29.97')),
#  (28, 'NC-17', 'Dhule (Dhulia)', Decimal('29.97')),
#  (22, 'PG', 'Zhoushan', Decimal('29.97')),
#  (28, 'PG', 'Saint-Denis', Decimal('29.97')),
#  (22, 'PG', 'Bergamo', Decimal('29.97')),
#  (18, 'R', 'Cabuyao', Decimal('29.97')),
#  (21, 'R', 'Kanazawa', Decimal('29.97')),
#  (17, 'G', 'Tabora', Decimal('29.97')),
#  (6, 'NC-17', 'Joliet', Decimal('29.97')),
#  (11, 'NC-17', 'Matamoros', Decimal('29.97')),
#  (17, 'PG-13', 'London', Decimal('29.97')),
#  (19, 'PG-13', 'Siliguri (Shiliguri)', Decimal('29.97')),
#  (10, 'G', 'Otsu', Decimal('29.97')),
#  (30, 'G', 'Bat Yam', Decimal('29.97')),
#  (9, 'G', 'Lungtan', Decimal('29.97')),
#  (29, 'PG-13', 'Joliet', Decimal('29.97')),
#  (7, 'PG-13', 'Tianjin', Decimal('29.97')),
#  (12, 'NC-17', 'Tieli', Decimal('29.97')),
#  (10, 'PG', 'Talavera', Decimal('29.97')),
#  (17, 'PG-13', 'Erlangen', Decimal('29.97')),
#  (23, 'R', 'Shanwei', Decimal('29.97')),
#  (30, 'PG', 'Santiago de Compostela', Decimal('29.97')),
#  (8, 'PG', 'Songkhla', Decimal('29.97')),
#  (28, 'G', 'Zanzibar', Decimal('29.97')),
#  (19, 'PG', 'Laohekou', Decimal('29.97')),
#  (21, 'PG', 'Qomsheh', Decimal('29.97')),
#  (27, 'PG-13', 'Abha', Decimal('29.97')),
#  (8, 'PG', 'Santa Rosa', Decimal('29.97')),
#  (20, 'PG', 'Juiz de Fora', Decimal('29.97')),
#  (20, 'PG-13', 'Nyeri', Decimal('29.97')),
#  (12, 'NC-17', 'Wroclaw', Decimal('29.97')),
#  (2, 'G', 'Valle de Santiago', Decimal('29.97')),
#  (18, 'PG', 'Tambaram', Decimal('29.97')),
#  (29, 'NC-17', 'Addis Abeba', Decimal('29.97')),
#  (30, 'PG', 'Ponce', Decimal('29.97')),
#  (28, 'G', 'Simferopol', Decimal('29.97')),
#  (29, 'R', 'Yangor', Decimal('29.97')),
#  (15, 'PG', 'Sasebo', Decimal('29.97')),
#  (8, 'NC-17', 'Mahajanga', Decimal('29.97')),
#  (28, 'G', 'Rustenburg', Decimal('29.97')),
#  (7, 'G', 'Shahr-e Kord', Decimal('29.97')),
#  (27, 'G', 'Otsu', Decimal('29.97')),
#  (8, 'PG', 'Lipetsk', Decimal('29.97')),
#  (30, 'R', 'Funafuti', Decimal('29.97')),
#  (21, 'NC-17', 'Karnal', Decimal('29.97')),
#  (17, 'G', 'Basel', Decimal('29.97')),
#  (7, 'G', 'Salinas', Decimal('29.97')),
#  (30, 'G', 'Liepaja', Decimal('29.97')),
#  (20, 'PG-13', 'Leshan', Decimal('29.97')),
#  (29, 'PG', 'Meixian', Decimal('29.97')),
#  (24, 'PG', 'San Felipe del Progreso', Decimal('29.97')),
#  (30, 'PG', 'Sagamihara', Decimal('29.97')),
#  (28, 'R', 'Ilorin', Decimal('29.97')),
#  (29, 'PG', 'Memphis', Decimal('29.97')),
#  (15, 'G', 'Najafabad', Decimal('29.97')),
#  (30, 'PG-13', 'Uruapan', Decimal('29.97')),
#  (19, 'G', 'Vancouver', Decimal('29.97')),
#  (28, 'PG-13', 'Bradford', Decimal('29.97')),
#  (29, 'PG-13', 'Bergamo', Decimal('29.97')),
#  (16, 'R', 'Donostia-San Sebastin', Decimal('29.97')),
#  (18, 'PG-13', 'Nador', Decimal('29.97')),
#  (19, 'NC-17', 'Sal', Decimal('29.97')),
#  (17, 'G', 'Mwene-Ditu', Decimal('29.97')),
#  (7, 'PG', 'Yerevan', Decimal('29.97')),
#  (20, 'PG', 'Bucuresti', Decimal('29.97')),
#  (18, 'NC-17', 'Jhansi', Decimal('29.97')),
#  (19, 'R', 'Ashdod', Decimal('29.97')),
#  (6, 'G', 'Jinzhou', Decimal('29.97')),
#  (23, 'PG', 'Ourense (Orense)', Decimal('29.97')),
#  (1, 'NC-17', 'Owo', Decimal('29.97')),
#  (8, 'NC-17', 'Peoria', Decimal('29.97')),
#  (6, 'PG', 'Kolpino', Decimal('29.97')),
#  (19, 'NC-17', 'Qinhuangdao', Decimal('29.97')),
#  (27, 'NC-17', 'Citrus Heights', Decimal('29.97')),
#  (30, 'NC-17', 'Mosul', Decimal('29.97')),
#  (6, 'PG-13', 'Kalisz', Decimal('29.97')),
#  (19, 'G', 'Pudukkottai', Decimal('29.97')),
#  (29, 'R', 'Sawhaj', Decimal('29.97')),
#  (8, 'NC-17', 'Pereira', Decimal('29.97')),
#  (28, 'PG-13', 'Vancouver', Decimal('29.97')),
#  (30, 'R', 'Udaipur', Decimal('29.97')),
#  (12, 'R', 'Denizli', Decimal('29.97')),
#  (6, 'G', 'Southampton', Decimal('29.97')),
#  (30, 'G', 'Botosani', Decimal('29.97')),
#  (28, 'PG-13', 'Loja', Decimal('29.97')),
#  (27, 'NC-17', 'Kamakura', Decimal('29.97')),
#  (23, 'PG-13', 'Kursk', Decimal('29.97')),
#  (12, 'PG', 'Molodetno', Decimal('29.97')),
#  (1, 'R', 'Vila Velha', Decimal('29.97')),
#  (25, 'G', 'Vaduz', Decimal('29.97')),
#  (7, 'R', 'Benguela', Decimal('29.97')),
#  (25, 'PG', 'Kimberley', Decimal('29.97')),
#  (12, 'PG-13', 'Pingxiang', Decimal('29.97')),
#  (11, 'NC-17', 'Clarksville', Decimal('29.97')),
#  (12, 'PG', 'Pangkal Pinang', Decimal('29.97')),
#  (6, 'PG-13', 'Wroclaw', Decimal('29.97')),
#  (29, 'G', 'Ede', Decimal('29.97')),
#  (20, 'NC-17', 'al-Manama', Decimal('29.97')),
#  (10, 'PG-13', 'Santiago de los Caballeros', Decimal('29.97')),
#  (6, 'PG-13', 'Uttarpara-Kotrung', Decimal('29.97')),
#  (9, 'R', 'Tokat', Decimal('29.97')),
#  (19, 'NC-17', 'Pontianak', Decimal('29.97')),
#  (1, 'PG', 'Oshawa', Decimal('29.97')),
#  (29, 'R', 'Manchester', Decimal('29.97')),
#  (23, 'NC-17', 'Cape Coral', Decimal('29.97')),
#  (21, 'R', 'Hidalgo', Decimal('29.97')),
#  (23, 'PG', 'Vaduz', Decimal('29.97')),
#  (2, 'G', 'Pjatigorsk', Decimal('29.97')),
#  (21, 'PG-13', 'Dos Quebradas', Decimal('29.97')),
#  (2, 'R', 'Okayama', Decimal('29.97')),
#  (2, 'PG-13', 'Po', Decimal('29.97')),
#  (20, 'R', 'Tangail', Decimal('29.97')),
#  (5, 'G', 'Fontana', Decimal('29.97')),
#  (20, 'NC-17', 'Bag', Decimal('29.97')),
#  (11, 'R', 'Juazeiro do Norte', Decimal('29.97')),
#  (2, 'G', 'Hamilton', Decimal('29.97')),
#  (2, 'PG', 'Beni-Mellal', Decimal('29.97')),
#  (16, 'PG-13', 'Ourense (Orense)', Decimal('29.97')),
#  (27, 'PG-13', 'Kuching', Decimal('29.97')),
#  (23, 'NC-17', 'Emeishan', Decimal('29.97')),
#  (27, 'PG', 'Munger (Monghyr)', Decimal('29.97')),
#  (26, 'G', 'Baybay', Decimal('29.97')),
#  (22, 'G', 'Robamba', Decimal('29.97')),
#  (9, 'PG', 'Jhansi', Decimal('29.97')),
#  (20, 'G', 'Blumenau', Decimal('29.97')),
#  (19, 'PG-13', 'Bellevue', Decimal('29.97')),
#  (29, 'NC-17', 'Nanyang', Decimal('29.97')),
#  (2, 'R', 'Escobar', Decimal('29.97')),
#  (21, 'NC-17', 'Arak', Decimal('29.97')),
#  (21, 'PG-13', 'Kanchrapara', Decimal('29.97')),
#  (22, 'PG-13', 'Hanoi', Decimal('29.97')),
#  (26, 'NC-17', 'Bydgoszcz', Decimal('29.97')),
#  (18, 'R', 'Vancouver', Decimal('29.97')),
#  (8, 'R', 'Hsichuh', Decimal('29.97')),
#  (22, 'PG', 'Pangkal Pinang', Decimal('29.97')),
#  (20, 'PG-13', 'Sincelejo', Decimal('29.97')),
#  (30, 'PG', 'Uluberia', Decimal('29.97')),
#  (12, 'R', 'Jakarta', Decimal('29.97')),
#  (21, 'PG-13', 'Osmaniye', Decimal('29.97')),
#  (30, 'R', 'York', Decimal('29.97')),
#  (12, 'NC-17', 'Asuncin', Decimal('29.97')),
#  (11, 'PG-13', 'Almirante Brown', Decimal('29.97')),
#  (23, 'R', 'Bhilwara', Decimal('29.97')),
#  (17, 'NC-17', 'Lapu-Lapu', Decimal('29.97')),
#  (26, 'NC-17', 'Plock', Decimal('29.97')),
#  (19, 'R', 'Uruapan', Decimal('29.97')),
#  (12, 'NC-17', 'Binzhou', Decimal('29.97')),
#  (21, 'R', 'Sorocaba', Decimal('29.94')),
#  (27, 'PG-13', 'Skikda', Decimal('29.94')),
#  (21, 'NC-17', 'Southend-on-Sea', Decimal('29.94')),
#  (30, 'PG', 'Liepaja', Decimal('29.94')),
#  (12, 'NC-17', 'El Monte', Decimal('29.94')),
#  (9, 'PG', 'Chandrapur', Decimal('29.94')),
#  (21, 'PG-13', 'Jakarta', Decimal('29.94')),
#  (21, 'PG-13', 'Erlangen', Decimal('29.94')),
#  (30, 'PG', 'Ahmadnagar', Decimal('29.94')),
#  (27, 'G', 'Tabora', Decimal('29.94')),
#  (11, 'PG', 'Okara', Decimal('29.94')),
#  (1, 'PG', 'NDjamna', Decimal('29.94')),
#  (6, 'R', 'Novi Sad', Decimal('29.94')),
#  (19, 'NC-17', 'Lhokseumawe', Decimal('29.94')),
#  (20, 'NC-17', 'Talavera', Decimal('29.94')),
#  (20, 'R', 'Liaocheng', Decimal('29.94')),
#  (22, 'PG', 'So Bernardo do Campo', Decimal('29.94')),
#  (9, 'PG', 'Probolinggo', Decimal('29.94')),
#  (9, 'NC-17', 'Vinh', Decimal('29.94')),
#  (18, 'PG', 'Emmen', Decimal('29.94')),
#  (30, 'PG', 'Tieli', Decimal('29.94')),
#  (18, 'PG', 'Cuman', Decimal('29.94')),
#  (1, 'G', 'Hohhot', Decimal('29.94')),
#  (23, 'PG-13', 'Kakamigahara', Decimal('29.94')),
#  (17, 'NC-17', 'Tanauan', Decimal('29.94')),
#  (28, 'PG', 'Daugavpils', Decimal('29.94')),
#  (17, 'G', 'al-Manama', Decimal('29.94')),
#  (29, 'PG-13', 'Probolinggo', Decimal('29.94')),
#  (29, 'PG', 'Benguela', Decimal('29.94')),
#  (20, 'NC-17', 'Surakarta', Decimal('29.94')),
#  (27, 'PG', 'Tychy', Decimal('29.94')),
#  (28, 'PG-13', 'Tafuna', Decimal('29.94')),
#  (8, 'PG-13', 'Najafabad', Decimal('29.94')),
#  (30, 'R', 'Beira', Decimal('29.94')),
#  (11, 'G', 'Tegal', Decimal('29.94')),
#  (20, 'PG', 'Salzburg', Decimal('29.94')),
#  (11, 'PG-13', 'Buenaventura', Decimal('29.94')),
#  (18, 'NC-17', 'Palghat (Palakkad)', Decimal('29.94')),
#  (1, 'R', 'Ourense (Orense)', Decimal('29.94')),
#  (18, 'NC-17', 'Zaoyang', Decimal('29.94')),
#  (20, 'G', 'Parbhani', Decimal('29.94')),
#  (30, 'NC-17', 'Southampton', Decimal('29.94')),
#  (20, 'NC-17', 'Santiago de los Caballeros', Decimal('29.94')),
#  (30, 'NC-17', 'Ashqelon', Decimal('29.94')),
#  (2, 'NC-17', 'Qalyub', Decimal('29.94')),
#  (28, 'PG-13', 'Enshi', Decimal('29.94')),
#  (8, 'G', 'Aden', Decimal('29.94')),
#  (20, 'G', 'Najafabad', Decimal('29.94')),
#  (16, 'PG', 'Ede', Decimal('29.94')),
#  (21, 'PG', 'Southport', Decimal('29.94')),
#  (10, 'NC-17', 'Bislig', Decimal('29.94')),
#  (6, 'G', 'Hodeida', Decimal('29.94')),
#  (30, 'G', 'Dhule (Dhulia)', Decimal('29.94')),
#  (30, 'PG-13', 'Emeishan', Decimal('29.94')),
#  (30, 'NC-17', 'Toulon', Decimal('29.94')),
#  (8, 'PG-13', 'Torren', Decimal('29.94')),
#  (29, 'G', 'Batna', Decimal('29.94')),
#  (30, 'NC-17', 'South Hill', Decimal('29.94')),
#  (21, 'PG', 'Shubra al-Khayma', Decimal('29.94')),
#  (28, 'PG-13', 'Ourense (Orense)', Decimal('29.94')),
#  (19, 'G', 'Mukateve', Decimal('29.94')),
#  (30, 'PG-13', 'Sambhal', Decimal('29.94')),
#  (1, 'NC-17', 'Tartu', Decimal('29.94')),
#  (30, 'PG', 'Xintai', Decimal('29.94')),
#  (28, 'R', 'Grand Prairie', Decimal('29.94')),
#  (30, 'R', 'Jastrzebie-Zdrj', Decimal('29.94')),
#  (11, 'PG', 'Sanaa', Decimal('29.94')),
#  (30, 'R', 'Yamuna Nagar', Decimal('29.94')),
#  (10, 'G', 'La Romana', Decimal('29.94')),
#  (6, 'NC-17', 'Aden', Decimal('29.94')),
#  (17, 'NC-17', 'Compton', Decimal('29.94')),
#  (30, 'PG', 'Karnal', Decimal('29.94')),
#  (19, 'PG-13', 'Guadalajara', Decimal('29.94')),
#  (1, 'PG-13', 'Ife', Decimal('29.94')),
#  (23, 'PG-13', 'Graz', Decimal('29.94')),
#  (27, 'R', 'Nakhon Sawan', Decimal('29.94')),
#  (19, 'PG', 'Okara', Decimal('29.94')),
#  (18, 'NC-17', 'Addis Abeba', Decimal('29.94')),
#  (1, 'PG', 'Changhwa', Decimal('29.94')),
#  (22, 'G', 'Amersfoort', Decimal('29.94')),
#  (28, 'PG', 'Aurora', Decimal('29.94')),
#  (12, 'PG-13', 'Nyeri', Decimal('29.94')),
#  (27, 'PG-13', 'Lipetsk', Decimal('29.94')),
#  (28, 'PG-13', 'Lungtan', Decimal('29.94')),
#  (20, 'PG', 'Berhampore (Baharampur)', Decimal('29.94')),
#  (19, 'PG-13', 'Hiroshima', Decimal('29.94')),
#  (21, 'G', 'Fontana', Decimal('29.94')),
#  (19, 'PG', 'Memphis', Decimal('29.94')),
#  (19, 'R', 'Korolev', Decimal('29.94')),
#  (30, 'PG-13', 'Jurez', Decimal('29.94')),
#  (31, 'NC-17', 'Omdurman', Decimal('29.94')),
#  (10, 'R', 'Fuyu', Decimal('29.94')),
#  (28, 'R', 'Athenai', Decimal('29.94')),
#  (29, 'PG', 'Tonghae', Decimal('29.94')),
#  (19, 'NC-17', 'Bandar Seri Begawan', Decimal('29.94')),
#  (29, 'PG', 'Tokat', Decimal('29.94')),
#  (18, 'R', 'Uttarpara-Kotrung', Decimal('29.94')),
#  (17, 'PG-13', 'Patiala', Decimal('29.94')),
#  (23, 'G', 'Maikop', Decimal('29.94')),
#  (27, 'G', 'Charlotte Amalie', Decimal('29.94')),
#  (11, 'NC-17', 'Xiangfan', Decimal('29.94')),
#  (1, 'NC-17', 'Witten', Decimal('29.94')),
#  (23, 'PG', 'Nabereznyje Telny', Decimal('29.94')),
#  (27, 'R', 'Batman', Decimal('29.94')),
#  (17, 'PG', 'Jalib al-Shuyukh', Decimal('29.94')),
#  (21, 'PG', 'Pontianak', Decimal('29.94')),
#  (28, 'PG-13', 'Miyakonojo', Decimal('29.94')),
#  (2, 'PG', 'Kaduna', Decimal('29.94')),
#  (30, 'G', 'Rampur', Decimal('29.94')),
#  (15, 'PG', 'Pontianak', Decimal('29.94')),
#  (7, 'NC-17', 'Bandar Seri Begawan', Decimal('29.94')),
#  (29, 'G', 'Stockport', Decimal('29.94')),
#  (30, 'R', 'Jinchang', Decimal('29.94')),
#  (20, 'PG', 'Batna', Decimal('29.94')),
#  (30, 'R', 'Bhusawal', Decimal('29.94')),
#  (30, 'G', 'Izumisano', Decimal('29.94')),
#  (19, 'PG-13', 'Liepaja', Decimal('29.94')),
#  (20, 'G', 'Palghat (Palakkad)', Decimal('29.94')),
#  (30, 'PG-13', 'Omdurman', Decimal('29.94')),
#  (28, 'PG-13', 'Kuwana', Decimal('29.94')),
#  (12, 'NC-17', 'Tegal', Decimal('29.94')),
#  (12, 'PG-13', 'Ikerre', Decimal('29.94')),
#  (27, 'PG-13', 'Basel', Decimal('29.94')),
#  (27, 'R', 'Ozamis', Decimal('29.94')),
#  (6, 'NC-17', 'Guadalajara', Decimal('29.94')),
#  (21, 'R', 'Zhoushan', Decimal('29.94')),
#  (17, 'R', 'Kurashiki', Decimal('29.94')),
#  (31, 'NC-17', 'Ktahya', Decimal('29.94')),
#  (30, 'R', 'Baiyin', Decimal('29.94')),
#  (9, 'PG', 'Tuguegarao', Decimal('29.94')),
#  (30, 'G', 'Balikesir', Decimal('29.94')),
#  (27, 'NC-17', 'Kitwe', Decimal('29.94')),
#  (21, 'R', 'Tanshui', Decimal('29.94')),
#  (23, 'PG', 'Yaound', Decimal('29.94')),
#  (23, 'R', 'Chandrapur', Decimal('29.94')),
#  (2, 'G', 'Banjul', Decimal('29.94')),
#  (20, 'PG', 'Laiwu', Decimal('29.94')),
#  (17, 'PG-13', 'Cuauhtmoc', Decimal('29.94')),
#  (20, 'R', 'Garland', Decimal('29.94')),
#  (17, 'PG-13', 'Coquimbo', Decimal('29.94')),
#  (9, 'R', 'El Monte', Decimal('29.94')),
#  (18, 'PG', 'Eskisehir', Decimal('29.94')),
#  (22, 'PG-13', 'Omdurman', Decimal('29.94')),
#  (30, 'NC-17', 'Balikesir', Decimal('29.94')),
#  (21, 'R', 'Hoshiarpur', Decimal('29.94')),
#  (18, 'PG-13', 'Sanaa', Decimal('29.94')),
#  (14, 'R', 'Jaipur', Decimal('29.94')),
#  (28, 'PG', 'Tsuyama', Decimal('29.94')),
#  (20, 'PG-13', 'Chapra', Decimal('29.94')),
#  (15, 'PG-13', 'Qinhuangdao', Decimal('29.94')),
#  (19, 'G', 'Halle/Saale', Decimal('29.94')),
#  (18, 'G', 'Jaffna', Decimal('29.94')),
#  (18, 'NC-17', 'Lipetsk', Decimal('29.94')),
#  (19, 'PG-13', 'Donostia-San Sebastin', Decimal('29.94')),
#  (30, 'NC-17', 'Bandar Seri Begawan', Decimal('29.94')),
#  (17, 'G', 'Mit Ghamr', Decimal('29.94')),
#  (9, 'R', 'Tandil', Decimal('29.94')),
#  (9, 'PG-13', 'Richmond Hill', Decimal('29.94')),
#  (21, 'R', 'Ciudad del Este', Decimal('29.94')),
#  (10, 'NC-17', 'Jastrzebie-Zdrj', Decimal('29.94')),
#  (23, 'G', 'San Juan Bautista Tuxtepec', Decimal('29.94')),
#  (30, 'G', 'Goinia', Decimal('29.94')),
#  (9, 'R', 'Tianjin', Decimal('29.94')),
#  (8, 'NC-17', 'NDjamna', Decimal('29.94')),
#  (9, 'PG', 'Warren', Decimal('29.94')),
#  (17, 'NC-17', 'Celaya', Decimal('29.94')),
#  (28, 'R', 'Saint-Denis', Decimal('29.94')),
#  (30, 'PG', 'Banjul', Decimal('29.94')),
#  (30, 'PG', 'Baku', Decimal('29.94')),
#  (1, 'NC-17', 'Tanshui', Decimal('29.94')),
#  (17, 'NC-17', 'Kansas City', Decimal('29.94')),
#  (28, 'PG-13', 'Yerevan', Decimal('29.94')),
#  (1, 'PG', 'Meixian', Decimal('29.94')),
#  (17, 'PG', 'Tabriz', Decimal('29.94')),
#  (18, 'R', 'Papeete', Decimal('29.94')),
#  (30, 'PG', 'Higashiosaka', Decimal('29.91')),
#  (20, 'PG', 'Callao', Decimal('29.91')),
#  (30, 'G', 'Changzhou', Decimal('29.91')),
#  (17, 'NC-17', 'Lungtan', Decimal('29.91')),
#  (28, 'NC-17', 'Tel Aviv-Jaffa', Decimal('29.91')),
#  (9, 'G', 'Brindisi', Decimal('29.91')),
#  (1, 'R', 'Inegl', Decimal('29.91')),
#  (18, 'PG', 'Kurashiki', Decimal('29.91')),
#  (20, 'NC-17', 'Mwanza', Decimal('29.91')),
#  (27, 'PG', 'Kamarhati', Decimal('29.91')),
#  (20, 'PG-13', 'Lapu-Lapu', Decimal('29.91')),
#  (1, 'NC-17', 'Liaocheng', Decimal('29.88')),
#  (30, 'PG-13', 'Lilongwe', Decimal('26.97')),
#  (23, 'PG', 'Ife', Decimal('26.97')),
#  (15, 'NC-17', 'Bhavnagar', Decimal('26.97')),
#  (20, 'R', 'Cape Coral', Decimal('26.97')),
#  (19, 'PG', 'Aurora', Decimal('26.97')),
#  (6, 'R', 'Bchar', Decimal('26.97')),
#  (10, 'PG-13', 'NDjamna', Decimal('26.97')),
#  (21, 'R', 'Athenai', Decimal('26.97')),
#  (21, 'G', 'Kamyin', Decimal('26.97')),
#  (20, 'R', 'Alessandria', Decimal('26.97')),
#  (2, 'PG', 'Bradford', Decimal('26.97')),
#  ...]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>day</th>
#         <th>rating</th>
#         <th>city</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>G</td>
#         <td>San Bernardino</td>
#         <td>24.97</td>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>NC-17</td>
#         <td>Apeldoorn</td>
#         <td>23.95</td>
#     </tr>
#     <tr>
#         <td>21</td>
#         <td>NC-17</td>
#         <td>Belm</td>
#         <td>22.97</td>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>PG-13</td>
#         <td>Zanzibar</td>
#         <td>21.97</td>
#     </tr>
#     <tr>
#         <td>28</td>
#         <td>R</td>
#         <td>Mwanza</td>
#         <td>21.97</td>
#     </tr>
# </tbody></table></div>

# %% [markdown]
# ## Slicing
#
# Slicing is the reduction of the dimensionality of a cube by 1 e.g. 3 dimensions to 2, fixing one of the dimensions to a single value. In the example above, we have a 3-dimensional cube on day, rating, and country.
#
# TODO: Write a query that reduces the dimensionality of the above example by limiting the results to only include movies with a `rating` of "PG-13". Again, sort by revenue in descending order and limit to the first 20 rows. The first few rows of your output should match the table below.

# %%
# %%time
# %%sql

SELECT d.day, m.rating, c.city, sum(s.sales_amount)
FROM factsales AS s 
INNER JOIN dimdate AS d on s.date_key = d.date_key 
INNER JOIN dimmovie AS m on s.movie_key = m.movie_key
INNER JOIN dimcustomer AS c ON c.customer_key = s.customer_key
WHERE m.rating='PG-13'
GROUP BY (d.day, m.rating, c.city)
ORDER BY sum(s.sales_amount) DESC 
LIMIT 20;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 20 rows affected.
# CPU times: user 5.13 ms, sys: 0 ns, total: 5.13 ms
# Wall time: 26.8 ms
# [(30, 'PG-13', 'Zanzibar', Decimal('65.91')),
#  (28, 'PG-13', 'Dhaka', Decimal('59.91')),
#  (30, 'PG-13', 'Osmaniye', Decimal('56.91')),
#  (29, 'PG-13', 'Shimoga', Decimal('56.91')),
#  (21, 'PG-13', 'Asuncin', Decimal('56.85')),
#  (21, 'PG-13', 'Parbhani', Decimal('53.94')),
#  (30, 'PG-13', 'Nagareyama', Decimal('53.94')),
#  (20, 'PG-13', 'Baha Blanca', Decimal('53.94')),
#  (30, 'PG-13', 'Tanauan', Decimal('53.88')),
#  (17, 'PG-13', 'Ikerre', Decimal('53.85')),
#  (30, 'PG-13', 'Zhoushan', Decimal('50.94')),
#  (30, 'PG-13', 'Yerevan', Decimal('50.91')),
#  (30, 'PG-13', 'Newcastle', Decimal('50.91')),
#  (30, 'PG-13', 'Santa Rosa', Decimal('47.94')),
#  (20, 'PG-13', 'Santa Rosa', Decimal('47.94')),
#  (17, 'PG-13', 'Yantai', Decimal('47.94')),
#  (8, 'PG-13', 'Pontianak', Decimal('47.94')),
#  (1, 'PG-13', 'Moscow', Decimal('47.91')),
#  (20, 'PG-13', 'Johannesburg', Decimal('47.91')),
#  (30, 'PG-13', 'Toulouse', Decimal('47.91'))]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>day</th>
#         <th>rating</th>
#         <th>city</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>PG-13</td>
#         <td>Zanzibar</td>
#         <td>21.97</td>
#     </tr>
#     <tr>
#         <td>28</td>
#         <td>PG-13</td>
#         <td>Dhaka</td>
#         <td>19.97</td>
#     </tr>
#     <tr>
#         <td>29</td>
#         <td>PG-13</td>
#         <td>Shimoga</td>
#         <td>18.97</td>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>PG-13</td>
#         <td>Osmaniye</td>
#         <td>18.97</td>
#     </tr>
#     <tr>
#         <td>21</td>
#         <td>PG-13</td>
#         <td>Asuncin</td>
#         <td>18.95</td>
#     </tr>
# </tbody></table></div>

# %% [markdown]
# ## Dicing
# Dicing is creating a subcube with the same dimensionality but fewer values for  two or more dimensions.
#
# TODO: Write a query to create a subcube of the initial cube that includes moves with:
# * ratings of PG or PG-13
# * in the city of Bellevue or Lancaster
# * day equal to 1, 15, or 30
#
# The first few rows of your output should match the table below.

# %%
# %%time
# %%sql

SELECT d.day, m.rating, c.city, sum(s.sales_amount)
FROM factsales AS s 
INNER JOIN dimdate AS d on s.date_key = d.date_key 
INNER JOIN dimmovie AS m on s.movie_key = m.movie_key
INNER JOIN dimcustomer AS c ON c.customer_key = s.customer_key
WHERE m.rating IN ('PG', 'PG-13') 
AND c.city IN ('Bellevue', 'Lancaster')
AND day IN (1, 15, 30)
GROUP BY (d.day, m.rating, c.city)
ORDER BY sum(s.sales_amount) DESC 
LIMIT 20;
# Out:
#  * postgresql://student:***@127.0.0.1:5432/pagila_star
# 6 rows affected.
# CPU times: user 5.82 ms, sys: 0 ns, total: 5.82 ms
# Wall time: 14.6 ms
# [(30, 'PG', 'Lancaster', Decimal('38.94')),
#  (1, 'PG-13', 'Lancaster', Decimal('17.97')),
#  (30, 'PG-13', 'Bellevue', Decimal('11.97')),
#  (30, 'PG-13', 'Lancaster', Decimal('8.97')),
#  (15, 'PG-13', 'Bellevue', Decimal('5.94')),
#  (1, 'PG', 'Bellevue', Decimal('2.97'))]

# %% [markdown]
# <div class="p-Widget jp-RenderedHTMLCommon jp-RenderedHTML jp-mod-trusted jp-OutputArea-output jp-OutputArea-executeResult" data-mime-type="text/html"><table>
#     <tbody><tr>
#         <th>day</th>
#         <th>rating</th>
#         <th>city</th>
#         <th>revenue</th>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>PG</td>
#         <td>Lancaster</td>
#         <td>12.98</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>PG-13</td>
#         <td>Lancaster</td>
#         <td>5.99</td>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>PG-13</td>
#         <td>Bellevue</td>
#         <td>3.99</td>
#     </tr>
#     <tr>
#         <td>30</td>
#         <td>PG-13</td>
#         <td>Lancaster</td>
#         <td>2.99</td>
#     </tr>
#     <tr>
#         <td>15</td>
#         <td>PG-13</td>
#         <td>Bellevue</td>
#         <td>1.98</td>
#     </tr>
# </tbody></table></div>
